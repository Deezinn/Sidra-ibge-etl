# %% [markdown]
# ## Protótipo de uma pipeline sobre os dados do IBGE (SIDRA)
# ### Esse arquivo em específico tem o foco de trabalhar com a série abate_1092

# %%
import pandas as pd

dataframe = pd.read_csv('../../csv/abate_1092.csv', header=1)

print('--- Informações do Dataframe ---')
dataframe.info()

print('\n--- Dimensões do Dataframe (Linhas, Colunas) ---')
print(dataframe.shape)
# Out:
# --- Informações do Dataframe ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16129 entries, 0 to 16128
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   0                                       16129 non-null  int64
#  1   Nível Territorial (Código)              16129 non-null  object
#  2   Nível Territorial                       16129 non-null  object
#  3   Unidade de Medida (Código)              16129 non-null  object
#  4   Unidade de Medida                       16129 non-null  object
#  5   Valor                                   16129 non-null  object
#  6   Brasil e Unidade da Federação (Código)  16129 non-null  object
#  7   Brasil e Unidade da Federação           16129 non-null  object
#  8   Variável (Código)                       16129 non-null  object
#  9   Variável                                16129 non-null  object
# ...
